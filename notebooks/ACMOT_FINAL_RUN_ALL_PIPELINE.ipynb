# %% [markdown]
# # AC-MOT Final Run-All Pipeline
#
# Run All once on a Tesla T4. This notebook runs official TrackEval on the three replay finalists, selects the winner, executes the final YOLOv8n FP16 live benchmark, then runs official TrackEval on the final live predictions.

# %%
import urllib.request

SCRIPT_URL = 'https://raw.githubusercontent.com/AhmedCode110/ACMOT-Codex-V10Style-Portable/main/final_run_all_pipeline.py'
print('Loading current AC-MOT final orchestrator...')
with urllib.request.urlopen(SCRIPT_URL) as r:
    source = r.read().decode('utf-8')
print('Orchestrator loaded:', len(source), 'bytes')
exec(compile(source, '<final_run_all_pipeline.py>', 'exec'), globals(), globals())
